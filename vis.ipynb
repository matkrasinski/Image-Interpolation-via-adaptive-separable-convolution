# %%
import matplotlib.pyplot as plt
import cv2

# %%
first_image = cv2.imread("frame1.jpg", cv2.IMREAD_COLOR)
second_image = cv2.imread("adap_conv_model_interpolated_frame.jpg", cv2.IMREAD_COLOR)
third_image = cv2.imread("frame3.jpg", cv2.IMREAD_COLOR)

# %%
fig, axes = plt.subplots(1, 3, figsize=(30, 10))

axes[0].imshow(first_image)
axes[1].imshow(second_image)
axes[2].imshow(third_image)

for ax in axes:
    ax.axis("off")
